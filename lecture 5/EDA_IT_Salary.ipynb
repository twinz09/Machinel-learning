# %%
# Jhose Immanuel Sembiring
# 1103202047
# TK44G4
# IT Salary
# Dokumentasi ChatGPT : https://chat.openai.com/share/998434d0-1e3b-4c13-932a-fbbdb67c6457

# %% [markdown]
# ChatGPT Prompt: Beri kode untuk connect google drive ke google colab!

# %%
from google.colab import drive
# menghubungkan google drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ChatGPT Prompt: Beri kode untuk read dataset as dataframe dengan path "/content/drive/MyDrive/Semester8/Machine Learning/lecture 5/dataset/IT Salary Survey EU  2020.csv"

# %%
import pandas as pd

# Path ke dataset
file_path = "/content/drive/MyDrive/Semester8/Machine Learning/lecture 5/dataset/IT Salary Survey EU  2020.csv"

# Membaca dataset sebagai dataframe
df = pd.read_csv(file_path)

# Menampilkan lima baris pertama dari dataframe
df.head()
# Out:
#              Timestamp   Age Gender    City           Position   \
# 0  24/11/2020 11:14:15  26.0   Male  Munich   Software Engineer
# 1  24/11/2020 11:14:16  26.0   Male  Berlin   Backend Developer
# 2  24/11/2020 11:14:21  29.0   Male  Berlin   Software Engineer
# 3  24/11/2020 11:15:24  28.0   Male  Berlin  Frontend Developer
# 4  24/11/2020 11:15:46  37.0   Male  Berlin   Backend Developer
#
#   Total years of experience Years of experience in Germany Seniority level  \
# 0                         5                              3          Senior
# 1                         7                              4          Senior
# 2                        12                              6            Lead
# 3                         4                              1          Junior
# 4                        17                              6          Senior
#
#   Your main technology / programming language  \
# 0                                  TypeScript
# ...

# %%
# Menampilkan informasi ringkas tentang dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1253 entries, 0 to 1252
# Data columns (total 23 columns):
#  #   Column                                                                                                                   Non-Null Count  Dtype
# ---  ------                                                                                                                   --------------  -----
#  0   Timestamp                                                                                                                1253 non-null   object
#  1   Age                                                                                                                      1226 non-null   float64
#  2   Gender                                                                                                                   1243 non-null   object
# ...

# %% [markdown]
# ChatGPT Prompt: Beri petunjuk melakukan Exploratory Data Analysis!
#
# Exploratory Data Analysis (EDA) adalah proses analisis data untuk memahami struktur, pola, dan hubungan dalam dataset. Berikut adalah beberapa langkah umum dalam melakukan EDA:
#
# 1. **Pemahaman Awal Dataset**:
#    - Baca dokumentasi dataset (jika tersedia) untuk memahami arti dari setiap kolom.
#    - Tampilkan beberapa baris pertama dari dataframe untuk melihat struktur data.
#
# 2. **Pemeriksaan Tipe Data**:
#    - Periksa tipe data dari setiap kolom (numerik, kategorikal, dll.).
#    - Pastikan tipe data telah diinterpretasikan dengan benar oleh pandas.
#
# 3. **Penanganan Missing Values**:
#    - Identifikasi kolom yang memiliki nilai yang hilang (NaN/null).
#    - Tentukan strategi penanganan nilai yang hilang, seperti menghapus baris atau mengisi dengan nilai tertentu.
#
# 4. **Statistik Deskriptif**:
#    - Hitung statistik deskriptif untuk variabel numerik (mean, median, standar deviasi, dll.).
#    - Hitung distribusi variabel kategorikal (jumlah kategori, frekuensi masing-masing kategori, dll.).
#
# 5. **Visualisasi Data**:
#    - Gunakan plot seperti histogram, box plot, dan scatter plot untuk memvisualisasikan distribusi dan hubungan antar variabel.
#    - Gunakan teknik visualisasi yang sesuai dengan jenis data (numerik vs kategorikal).
#
# 6. **Eksplorasi Hubungan Antara Variabel**:
#    - Identifikasi hubungan antara variabel-variabel dalam dataset menggunakan scatter plot, heatmap, atau pair plot.
#    - Gunakan koefisien korelasi untuk mengukur hubungan linier antara variabel numerik.
#
# 7. **Penemuan Pola atau Insight**:
#    - Identifikasi pola menarik, anomali, atau insight menarik dalam data.
#    - Gunakan teknik seperti clustering atau analisis asosiasi untuk menemukan pola yang lebih kompleks.
#
# 8. **Validasi Asumsi atau Hipotesis**:
#    - Jika ada, uji asumsi atau hipotesis yang mungkin berlaku dalam dataset.
#    - Gunakan teknik statistik atau inferensi untuk menguji hipotesis.
#
# 9. **Iterasi dan Perbaikan**:
#    - Iterasikan langkah-langkah EDA jika diperlukan untuk memperdalam pemahaman Anda tentang data.
#    - Perbaiki dan perbaiki masalah yang Anda temui selama proses EDA.
#
# 10. **Dokumentasi Hasil**:
#     - Dokumentasikan temuan dan insight penting dari analisis data.
#     - Persiapkan laporan atau presentasi yang jelas dan informatif untuk berbagi hasil EDA dengan pemangku kepentingan lainnya.
#
# Dengan mengikuti langkah-langkah ini, Anda dapat melakukan EDA yang komprehensif untuk memahami dataset Anda dengan baik.

# %% [markdown]
# ChatGPT Prompt: Ben kode untuk mendapatkan summary statistical dan dataframe

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1253 entries, 0 to 1252
# Data columns (total 23 columns):
#  #   Column                                                                                                                   Non-Null Count  Dtype
# ---  ------                                                                                                                   --------------  -----
#  0   Timestamp                                                                                                                1253 non-null   object
#  1   Age                                                                                                                      1226 non-null   float64
#  2   Gender                                                                                                                   1243 non-null   object
# ...

# %%
# Menampilkan summary statistik
df.describe()
# Out:
#                Age  Yearly brutto salary (without bonus and stocks) in EUR  \
# count  1226.000000                                       1.253000e+03
# mean     32.509788                                       8.027904e+07
# std       5.663804                                       2.825061e+09
# min      20.000000                                       1.000100e+04
# 25%      29.000000                                       5.880000e+04
# 50%      32.000000                                       7.000000e+04
# 75%      35.000000                                       8.000000e+04
# max      69.000000                                       1.000000e+11
#
#        Annual brutto salary (without bonus and stocks) one year ago. Only answer if staying in the same country  \
# count                                       8.850000e+02
# mean                                        6.322459e+05
# std                                         1.680508e+07
# ...

# %%
# Memilih kolom-kolom yang spesifik
selected_features = ["Total years of experience",
                     "Years of experience in Germany",
                     "Yearly bonus + stocks in EUR",
                     "Annual bonus+stocks one year ago. Only answer if staying in same country",
                     "Number of vacation days",
                     "Сontract duration",
                     "Company size"]

# Menampilkan lima baris teratas dari fitur-fitur yang dipilih
df[selected_features].head()
# Out:
#   Total years of experience Years of experience in Germany  \
# 0                         5                              3
# 1                         7                              4
# 2                        12                              6
# 3                         4                              1
# 4                        17                              6
#
#   Yearly bonus + stocks in EUR  \
# 0                         5000
# 1                          NaN
# 2                       120000
# 3                          NaN
# 4                          NaN
#
#   Annual bonus+stocks one year ago. Only answer if staying in same country  \
# 0                                              10000
# 1                                               5000
# 2                                             100000
# 3                                                NaN
# 4                                                NaN
#
#   Number of vacation days   Сontract duration Company size
# ...

# %% [markdown]
# ChatGPT Prompt: Beri kode untuk mengubah fitur-fitur tertentu berikut: "Total years of experience", "Years of experience in Germany", "Yearly bonus + stocks in EUR", "Annual bonus+stocks one year ago. Only answer if staying in same country", "Number of vacation days" bertipe data
# numerik!

# %%
# List fitur-fitur yang ingin diubah menjadi numerik
numeric_features = ["Total years of experience",
                    "Years of experience in Germany",
                    "Yearly bonus + stocks in EUR",
                    "Annual bonus+stocks one year ago. Only answer if staying in same country",
                    "Number of vacation days"]

# Mengubah tipe data fitur-fitur tersebut menjadi numerik
df[numeric_features] = df[numeric_features].apply(pd.to_numeric, errors='coerce')

# # Menampilkan lima baris teratas setelah perubahan tipe data
# df[numeric_features].head()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1253 entries, 0 to 1252
# Data columns (total 23 columns):
#  #   Column                                                                                                                   Non-Null Count  Dtype
# ---  ------                                                                                                                   --------------  -----
#  0   Timestamp                                                                                                                1253 non-null   object
#  1   Age                                                                                                                      1226 non-null   float64
#  2   Gender                                                                                                                   1243 non-null   object
# ...

# %%
# Membuat kamus untuk pemetaan nama fitur yang lama ke nama fitur yang baru
rename_mapping = {
    "Total years of experience": "Total experience",
    "Years of experience in Germany": "Experience in Germany",
    "Your main technology / programming language": "Main programming language",
    "Other technologies/programming languages you use often": "Other programming languages",
    "Yearly brutto salary (without bonus and stocks) in EUR": "Yearly brutto salary",
    "Yearly bonus + stocks in EUR": "Yearly bonus and stocks",
    "Annual brutto salary (without bonus and stocks) one year ago. Only answer if staying in the same country": "Previous yearly brutto salary",
    "Annual bonus+stocks one year ago. Only answer if staying in same country": "Previous yearly bonus and stocks",
    "Number of vacation days": "Vacation days",
    "Main language at work": "Main work language",
    "Have you lost your job due to the coronavirus outbreak?": "Lost job due to COVID-19",
    "Have you been forced to have a shorter working week (Kurzarbeit)? If yes, how many hours per week": "Kurzarbeit hours per week",
    "Have you received additional monetary support from your employer due to Work From Home? If yes, how much in 2020 in EUR": "Additional monetary support in 2020"
}

# Memperbarui nama-nama fitur dalam dataframe
df.rename(columns=rename_mapping, inplace=True)

# %% [markdown]
# ChatGPT Prompt: Beri kode untuk menampilakn baris yang memiliki null value

# %%
# Mengidentifikasi baris-baris yang memiliki setidaknya satu nilai null
rows_with_null = df[df.isnull().any(axis=1)]

# Menampilkan baris-baris yang memiliki nilai null
rows_with_null
# Out:
#                 Timestamp   Age Gender         City  \
# 0     24/11/2020 11:14:15  26.0   Male       Munich
# 1     24/11/2020 11:14:16  26.0   Male       Berlin
# 2     24/11/2020 11:14:21  29.0   Male       Berlin
# 3     24/11/2020 11:15:24  28.0   Male       Berlin
# 4     24/11/2020 11:15:46  37.0   Male       Berlin
# ...                   ...   ...    ...          ...
# 1247  18/01/2021 11:50:02  34.0   Male       Zurich
# 1248  18/01/2021 15:05:50  31.0   Male       Berlin
# 1249  18/01/2021 17:46:02  33.0   Male       Berlin
# 1250  18/01/2021 23:20:35  39.0   Male       Munich
# 1251  19/01/2021 10:17:58  26.0   Male  Saarbrücken
#
#                                    Position   Total experience  \
# 0                          Software Engineer               5.0
# 1                          Backend Developer               7.0
# 2                          Software Engineer              12.0
# 3                         Frontend Developer               4.0
# ...

# %% [markdown]
# ChatGPT Prompt: Beri kode untuk mengisi baris dari fitur "Kurzarbeit hours per week" yang memiliki null value dengan nilai "0"

# %%
# Mengisi nilai null dalam kolom "Kurzarbeit hours per week" dengan nilai "0"
df["Kurzarbeit hours per week"].fillna(0, inplace=True)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1253 entries, 0 to 1252
# Data columns (total 23 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Timestamp                            1253 non-null   object
#  1   Age                                  1226 non-null   float64
#  2   Gender                               1243 non-null   object
#  3   City                                 1253 non-null   object
#  4   Position                             1247 non-null   object
#  5   Total experience                     1230 non-null   float64
#  6   Experience in Germany                1194 non-null   float64
#  7   Seniority level                      1241 non-null   object
#  8   Main programming language            1126 non-null   object
#  9   Other programming languages          1096 non-null   object
#  10  Yearly brutto salary                 1253 non-null   float64
# ...

# %% [markdown]
# ChatGPT Prompt: Beri kode untuk menampilkan pie diagram chart untuk fitur Age dengan min 20, max 69

# %%
import matplotlib.pyplot as plt
import pandas as pd

# menentukan rentan nilai umur
min_age = 20
max_age = 69

# mengelompokkan data umur ke dalam kategori
bins = [min_age, 30, 40, 50, 60, max_age]
labels = ['20-30', '31-40', '41-50', '51-60', '61+']
df['Age_group'] = pd.cut(df['Age'], bins=bins, labels=labels, right=False)

# Menghitung jumlah individu dalam setiap kelompok usia
age_counts = df['Age_group'].value_counts()

# Membuat pie chart
plt.figure(figsize=(8, 6))
plt.pie(age_counts, labels=age_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Distribusi Usia')
plt.axis('equal')  # Memastikan lingkaran memiliki aspek rasio yang sama
plt.show()

# %% [markdown]
# ChatGPT Prompt: Beri kode untuk menampilkan baris data yang memiliki Age "51-60", "60+"

# %%
# Memfilter baris dengan nilai '51-60' atau '60+' pada kolom 'Age'
filtered_rows = df.loc[df['Age_group'].isin(['51-60', '60+'])]

# Menampilkan baris-baris yang telah difilter
filtered_rows
# Out:
#                 Timestamp   Age Gender        City           Position   \
# 23    24/11/2020 11:23:11  59.0   Male      Berlin   Backend Developer
# 232   24/11/2020 13:53:01  56.0   Male  Ingolstadt   Software Engineer
# 233   24/11/2020 13:54:47  53.0   Male   Stuttgart  Frontend Developer
# 403   24/11/2020 19:48:24  50.0   Male      Berlin   Software Engineer
# 673   25/11/2020 18:56:02  51.0   Male      Berlin   Software Engineer
# 955   30/11/2020 12:56:08  54.0   Male      Milano              Sales
# 1159  14/12/2020 08:55:24  56.0   Male      Munich   Software Engineer
# 1182  20/12/2020 01:48:34  54.0   Male      Munich   Software Engineer
# 1232  08/01/2021 16:12:36  52.0   Male   Stuttgart   Software Engineer
#
#       Total experience  Experience in Germany Seniority level  \
# 23                30.0                   30.0          Senior
# 232                9.0                    9.0          Senior
# 233               15.0                   15.0          Senior
# ...

# %% [markdown]
# Buat kode untuk menampilkan Histogram untuk setiap fitur : "Experience in Germany", "Seniority level",  "Yearly brutto salary", "Yearly bonus and stocks", "Previous yearly brutto salary", "Previous yearly bonus and stocks", "Vacation days"

# %%
import matplotlib.pyplot as plt

# List fitur yang ingin diplot sebagai histogram
features = ["Experience in Germany", "Seniority level", "Yearly brutto salary",
            "Yearly bonus and stocks", "Previous yearly brutto salary",
            "Previous yearly bonus and stocks", "Vacation days"]

# Membuat subplot untuk setiap histogram
fig, axs = plt.subplots(len(features), 1, figsize=(10, 8*len(features)))

# Melakukan loop untuk setiap fitur dan membuat histogram
for i, feature in enumerate(features):
    axs[i].hist(df[feature].dropna(), bins=20, color='skyblue', edgecolor='black')
    axs[i].set_title(f'Histogram of {feature}')
    axs[i].set_xlabel(feature)
    axs[i].set_ylabel('Frequency')

plt.tight_layout()
plt.show()

# %% [markdown]
# Buat kode untuk menampilkan Box Plot untuk setiap fitur : "Experience in Germany", "Seniority level",  "Yearly brutto salary", "Yearly bonus and stocks", "Previous yearly brutto salary", "Previous yearly bonus and stocks", "Vacation days"

# %%
import matplotlib.pyplot as plt

# List fitur yang ingin diplot sebagai box plot
features = ["Experience in Germany", "Seniority level", "Yearly brutto salary",
            "Yearly bonus and stocks", "Previous yearly brutto salary",
            "Previous yearly bonus and stocks", "Vacation days"]

# Membuat subplot untuk setiap box plot
fig, axs = plt.subplots(len(features), 1, figsize=(10, 8*len(features)))

# Melakukan loop untuk setiap fitur dan membuat box plot
for i, feature in enumerate(features):
    axs[i].boxplot(df[feature].dropna())
    axs[i].set_title(f'Box Plot of {feature}')
    axs[i].set_xlabel(feature)
    axs[i].set_ylabel('Value')

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-99-b66b4e347dde> in <cell line: 12>()
#      11 # Melakukan loop untuk setiap fitur dan membuat box plot
#      12 for i, feature in enumerate(features):
# ---> 13     axs[i].boxplot(df[feature].dropna())
#      14     axs[i].set_title(f'Box Plot of {feature}')
#      15     axs[i].set_xlabel(feature)
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1440     def inner(ax, *args, data=None, **kwargs):
#    1441         if data is None:
# -> 1442             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1443
#    1444         bound = new_sig.bind(ax, *args, **kwargs)
#
# ...

# %% [markdown]
# beri kode untuk menampilkan heat map dari fitu-fitur numerik: "Experience in Germany", "Seniority level",  "Yearly brutto salary", "Yearly bonus and stocks", "Previous yearly brutto salary", "Previous yearly bonus and stocks", "Vacation days"

# %%
correlation_matrix = df

# Selecting only numeric columns
numeric_columns = df.select_dtypes(include=['float64', 'int64'])

# Computing the correlation between numeric features
correlation_matrix = numeric_columns.corr()

# Displaying the correlation heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", annot_kws={"size": 10})
plt.title('Correlation between Features')
plt.show().corr()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-104-74c7a3b73251> in <cell line: 13>()
#      11 sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", annot_kws={"size": 10})
#      12 plt.title('Correlation between Features')
# ---> 13 plt.show().corr()
#
# AttributeError: 'NoneType' object has no attribute 'corr'
